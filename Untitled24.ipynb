# %%
# !pip install chromadb transformers pillow torch
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 4.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.4/21.4 MB 80.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 26.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 66.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.3/103.3 kB 9.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.4/17.4 MB 87.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.4/132.4 kB 6.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.0/220.0 kB 16.3 MB/s eta 0:00:00
# ...

# %%
image_folder = "images"
ids = []
embeddings = []
metadatas = []

if not os.path.exists(image_folder):
    print(f"WARNING: Folder '{image_folder}' does not exist. Please create it and upload images!")
else:
    print(f"Indexing images from {image_folder}...")
    files = [f for f in os.listdir(image_folder) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]

    if not files:
        print("No images found! Please upload .jpg files to the 'images' folder.")

    for filename in files:
        path = os.path.join(image_folder, filename)
        try:
            vector = get_image_embedding(path)
            ids.append(filename)
            embeddings.append(vector)
            metadatas.append({"source": filename})
            print(f"Indexed: {filename}")
        except Exception as e:
            print(f"Error indexing {filename}: {e}")

    if ids:
        collection.add(embeddings=embeddings, ids=ids, metadatas=metadatas)
        print(f"Finished! {len(ids)} images in database.")
# Out:
# Indexing images from images...
# Indexed: burger.jpg
# Indexed: sushi.jpg
# Indexed: pasta.jpg
# Indexed: pizza.jpg
# Indexed: salad.jpg
# Finished! 5 images in database.

# %%
import os
import chromadb
from PIL import Image
from transformers import CLIPProcessor, CLIPModel
import torch

print("Loading CLIP Model...")
model_id = "openai/clip-vit-base-patch32"
model = CLIPModel.from_pretrained(model_id)
processor = CLIPProcessor.from_pretrained(model_id)

print("Initializing ChromaDB...")
client = chromadb.Client()
# ⚠️ IMPORTANT: Delete old collection so we don't mix bad vectors with good ones
try:
    client.delete_collection("food_gallery")
except:
    pass
collection = client.get_or_create_collection(name="food_gallery")

def get_image_embedding(image_path):
    image = Image.open(image_path)
    inputs = processor(images=image, return_tensors="pt")
    image_features = model.get_image_features(**inputs)

    # 👇 THE FIX: Normalize the vector to length 1
    image_features = image_features / image_features.norm(p=2, dim=-1, keepdim=True)

    return image_features.detach().numpy().flatten().tolist()

def get_text_embedding(text):
    inputs = processor(text=[text], return_tensors="pt", padding=True)
    text_features = model.get_text_features(**inputs)

    # 👇 THE FIX: Normalize the vector to length 1
    text_features = text_features / text_features.norm(p=2, dim=-1, keepdim=True)

    return text_features.detach().numpy().flatten().tolist()
# Out:
# Loading CLIP Model...
# Initializing ChromaDB...

# %%
# @title
from IPython.display import display

query = "purple vegetable slices"  # <--- Try "sushi rice" or "white rice" if this fails

print(f"Searching for: '{query}'")
query_vector = get_text_embedding(query)

# Get Top 3 results to see what else it considered
results = collection.query(
    query_embeddings=[query_vector],
    n_results=3,
    include=["metadatas", "distances"] # <--- Ask for scores
)

print("\n--- RESULTS ---")
for i in range(len(results['ids'][0])):
    filename = results['ids'][0][i]
    score = results['distances'][0][i] # Distance (0 is identical, 1 is opposite)

    print(f"#{i+1}: {filename} (Distance: {score:.4f})")

    # Only show image if it's a reasonable match (e.g. distance < 1.5)
    display(Image.open(os.path.join(image_folder, filename)).resize((200, 150)))
# Out:
# Searching for: 'purple vegetable slices'
#
# --- RESULTS ---
# #1: sushi.jpg (Distance: 1.5061)
# <PIL.Image.Image image mode=RGB size=200x150>
# #2: salad.jpg (Distance: 1.5617)
# <PIL.Image.Image image mode=RGB size=200x150>
# #3: pizza.jpg (Distance: 1.5676)
# <PIL.Image.Image image mode=RGB size=200x150>
